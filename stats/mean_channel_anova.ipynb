# %%
import pandas as pd
from IPython.display import HTML
import numpy as np

data = pd.read_csv('../data/mean_channel_data_with_button.csv')
labels = list(data.columns.values)
del labels[0]
del labels[0]
target = data['Phenotype']
del data['Subject']
del data['Phenotype']

# %%
from sklearn import preprocessing
from sklearn import feature_selection

# sklearn doesn't have t-test, so looking at anova f-values.

data = preprocessing.Imputer().fit_transform(data, target)
f_values = feature_selection.f_classif(data, target)[0]
HTML(pd.DataFrame(data=f_values, index=labels).sort_values(0, ascending=False).to_html())
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>0</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>ButtonAcc</th>
#       <td>21.211051</td>
#     </tr>
#     <tr>
#       <th>P3aDAvgA</th>
#       <td>21.061388</td>
#     </tr>
#     <tr>
#       <th>P3aDA</th>
#       <td>15.368724</td>
#     </tr>
#     <tr>
#       <th>FalseAlarm</th>
#       <td>11.753298</td>
#     </tr>
#     <tr>
#       <th>P3bTA</th>
#       <td>10.490405</td>
#     </tr>
#     <tr>
#       <th>P200DAvgA</th>
#       <td>10.393745</td>
#     </tr>
#     <tr>
#       <th>P200DA</th>
#       <td>10.127999</td>
#     </tr>
#     <tr>
#       <th>Missing</th>
#       <td>10.041669</td>
#     </tr>
#     <tr>
#       <th>N100SAvgA</th>
#       <td>8.792685</td>
#     </tr>
#     <tr>
#       <th>N100TAvgA</th>
#       <td>7.205419</td>
#     </tr>
#     <tr>
#       <th>P3bTL</th>
#       <td>5.829370</td>
#     </tr>
#     <tr>
#       <th>MedReact</th>
#       <td>5.760279</td>
#     </tr>
#     <tr>
#       <th>N200TAvgA</th>
#       <td>4.076489</td>
#     </tr>
#     <tr>
#       <th>N100DAvgA</th>
#       <td>3.071297</td>
#     </tr>
#     <tr>
#       <th>P200SA</th>
#       <td>2.585487</td>
#     </tr>
#     <tr>
#       <th>P50SAvgA</th>
#       <td>2.543098</td>
#     </tr>
#     <tr>
#       <th>N200TA</th>
#       <td>2.480714</td>
#     </tr>
#     <tr>
#       <th>N200TL</th>
#       <td>2.266107</td>
#     </tr>
#     <tr>
#       <th>P200SL</th>
#       <td>2.001036</td>
#     </tr>
#     <tr>
#       <th>P3bTAvgA</th>
#       <td>1.359627</td>
#     </tr>
#     <tr>
#       <th>P200SAvgA</th>
#       <td>0.827942</td>
#     </tr>
#     <tr>
#       <th>P50TAvgA</th>
#       <td>0.585124</td>
#     </tr>
#     <tr>
#       <th>P200DL</th>
#       <td>0.445806</td>
#     </tr>
#     <tr>
#       <th>P200TA</th>
#       <td>0.362598</td>
#     </tr>
#     <tr>
#       <th>P200TAvgA</th>
#       <td>0.343030</td>
#     </tr>
#     <tr>
#       <th>P200TL</th>
#       <td>0.310617</td>
#     </tr>
#     <tr>
#       <th>SlowWaveTAvgA</th>
#       <td>0.230473</td>
#     </tr>
#     <tr>
#       <th>P50DAvgA</th>
#       <td>0.166334</td>
#     </tr>
#     <tr>
#       <th>P3aDL</th>
#       <td>0.084340</td>
#     </tr>
#   </tbody>
# </table>
